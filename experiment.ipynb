# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
# import sys
# print(sys.executable)    # To check which Python interpreter is being used

# %%
import arxiv

def search_arxiv(query: str, top_k: int = 5):
    """
    Search arXiv for a query and return top_k results.
    """
    search = arxiv.Search(
        query=query,
        max_results=top_k,
        sort_by=arxiv.SortCriterion.Relevance
    )

    papers = []
    for result in search.results():
        papers.append({
            "title": result.title,
            "authors": [str(a) for a in result.authors],
            "published": result.published,
            "summary": result.summary,
            "pdf_url": result.pdf_url,
        })
    return papers

if __name__ == "__main__":
    query = "machine learning in healthcare"
    papers = search_arxiv(query, top_k=3)
    for p in papers:
        print(papers.index(p)+1)
        print(f"PDF URL: {p['pdf_url']}")
        print(f"Title: {p['title']}")
        print(f"Authors: {' '.join(p['authors'])}")
        print(f"Published: {p['published']}")
        print(f"Summary: {p['summary']}")
        print('*****************')
# Out:
# C:\Users\abhir\AppData\Local\Temp\ipykernel_25380\2303336763.py:14: DeprecationWarning: The 'Search.results' method is deprecated, use 'Client.results' instead
#   for result in search.results():
# 1
# PDF URL: https://arxiv.org/pdf/2303.15563v1
# Title: Privacy-preserving machine learning for healthcare: open challenges and future perspectives
# Authors: Alejandro Guerra-Manzanares L. Julian Lechuga Lopez Michail Maniatakos Farah E. Shamout
# Published: 2023-03-27 19:20:51+00:00
# Summary: Machine Learning (ML) has recently shown tremendous success in modeling various healthcare prediction tasks, ranging from disease diagnosis and prognosis to patient treatment. Due to the sensitive nature of medical data, privacy must be considered along the entire ML pipeline, from model training to inference. In this paper, we conduct a review of recent literature concerning Privacy-Preserving Machine Learning (PPML) for healthcare. We primarily focus on privacy-preserving training and inference-as-a-service, and perform a comprehensive review of existing trends, identify challenges, and discuss opportunities for future research directions. The aim of this review is to guide the development of private and efficient ML models in healthcare, with the prospects of translating research efforts into real-world settings.
# *****************
# 2
# PDF URL: https://arxiv.org/pdf/1706.01513v2
# Title: Beyond Volume: The Impact of Complex Healthcare Data on the Machine Learning Pipeline
# Authors: Keith Feldman Louis Faust Xian Wu Chao Huang Nitesh V. Chawla
# Published: 2017-06-01 20:34:41+00:00
# Summary: From medical charts to national census, healthcare has traditionally operated under a paper-based paradigm. However, the past decade has marked a long and arduous transformation bringing healthcare into the digital age. Ranging from electronic health records, to digitized imaging and laboratory reports, to public health datasets, today, healthcare now generates an incredible amount of digital information. Such a wealth of data presents an exciting opportunity for integrated machine learning solutions to address problems across multiple facets of healthcare practice and administration. Unfortunately, the ability to derive accurate and informative insights requires more than the ability to execute machine learning models. Rather, a deeper understanding of the data on which the models are run is imperative for their success. While a significant effort has been undertaken to develop models able to process the volume of data obtained during the analysis of millions of digitalized patient records, it is important to remember that volume represents only one aspect of the data. In fact, drawing on data from an increasingly diverse set of sources, healthcare data presents an incredibly complex set of attributes that must be accounted for throughout the machine learning pipeline. This chapter focuses on highlighting such challenges, and is broken down into three distinct components, each representing a phase of the pipeline. We begin with attributes of the data accounted for during preprocessing, then move to considerations during model building, and end with challenges to the interpretation of model output. For each component, we present a discussion around data as it relates to the healthcare domain and offer insight into the challenges each may impose on the efficiency of machine learning techniques.
# *****************
# 3
# PDF URL: https://arxiv.org/pdf/2306.04338v1
# Title: Changing Data Sources in the Age of Machine Learning for Official Statistics
# Authors: Cedric De Boom Michael Reusens
# Published: 2023-06-07 11:08:12+00:00
# Summary: Data science has become increasingly essential for the production of official statistics, as it enables the automated collection, processing, and analysis of large amounts of data. With such data science practices in place, it enables more timely, more insightful and more flexible reporting. However, the quality and integrity of data-science-driven statistics rely on the accuracy and reliability of the data sources and the machine learning techniques that support them. In particular, changes in data sources are inevitable to occur and pose significant risks that are crucial to address in the context of machine learning for official statistics.
#   This paper gives an overview of the main risks, liabilities, and uncertainties associated with changing data sources in the context of machine learning for official statistics. We provide a checklist of the most prevalent origins and causes of changing data sources; not only on a technical level but also regarding ownership, ethics, regulation, and public perception. Next, we highlight the repercussions of changing data sources on statistical reporting. These include technical effects such as concept drift, bias, availability, validity, accuracy and completeness, but also the neutrality and potential discontinuation of the statistical offering. We offer a few important precautionary measures, such as enhancing robustness in both data sourcing and statistical techniques, and thorough monitoring. In doing so, machine learning-based official statistics can maintain integrity, reliability, consistency, and relevance in policy-making, decision-making, and public discourse.
# *****************

# %%
idx=int(input("Enter the paper number to ask any question about:"))
qa_paper=papers[idx-1]['pdf_url']

# %%
input_paper=qa_paper+'.pdf'

# %%
input_paper
# Out:
# 'https://arxiv.org/pdf/2303.15563v1'

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings

# Step 1: Load PDF
loader = PyPDFLoader(input_paper)
docs = loader.load()

# Step 2: Split into chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
documents = text_splitter.split_documents(docs)

# Step 3: Create embeddings
embedding_model = HuggingFaceEmbeddings()
# Out:
# C:\Users\abhir\AppData\Local\Temp\ipykernel_25380\2513085679.py:15: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embedding_model = HuggingFaceEmbeddings()

# %%
# Step 4: Build vector database
vectordb1 = FAISS.from_documents(documents, embedding_model)

# Step 5: Create retriever
retriever1 = vectordb1.as_retriever()

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_template(
    """
you are a expert in research paper analysis. Answer the following question based only on the provided context:
<context>
{context}
</context>
"""
)

# %%
import os
import certifi
os.environ['SSL_CERT_FILE'] = certifi.where()

# %%
from langchain_google_genai import GoogleGenerativeAI

# %%
# from getpass import getpass

# api_key = getpass()
# import os

api_key=os.getenv('GOOGLE_API_KEY')

# %%
llm = GoogleGenerativeAI(model="gemini-2.5-flash", google_api_key=api_key)
print(
    llm.invoke(
        "What are some of the pros and cons of Python as a programming language?"
    )
)
# Out:
# Python is one of the most popular programming languages today, known for its versatility and readability. Like any tool, it has its strengths and weaknesses.
#
# Here's a breakdown of the pros and cons of Python:
#
# ---
#
# ### Pros of Python
#
# 1.  **Ease of Learning and Readability:**
#     *   **Pro:** Python has a simple, clean, and highly readable syntax that resembles natural language. This makes it very easy for beginners to pick up and for experienced developers to understand code quickly. The use of indentation for code blocks enforces a consistent style.
#
# 2.  **Extensive Libraries and Frameworks ("Batteries Included"):**
#     *   **Pro:** Python boasts a vast ecosystem of libraries and frameworks that cater to almost every imaginable task.
#         *   **Web Development:** Django, Flask, FastAPI
#         *   **Data Science & Machine Learning:** NumPy, Pandas, Scikit-learn, TensorFlow, PyTorch
#         *   **Scientific Computing:** SciPy, Matplotlib
#         *   **Automation & Scripting:** Built-in modules, `os`, `sys`, `subprocess`
#         *   **GUI Development:** Tkinter, PyQt, Kivy
#         *   This rich collection significantly speeds up development as developers rarely need to build things from scratch.
#
# 3.  **Versatility and Wide Range of Applications:**
#     *   **Pro:** Python is a general-purpose language suitable for a multitude of applications:
#         *   Web Development (backend)
#         *   Data Science, Machine Learning, and AI
#         *   Scientific and Numeric Computing
#         *   Automation and Scripting
#         *   Desktop GUI Applications
#         *   Game Development (less common but possible)
#         *   Education and Prototyping
#
# 4.  **Large and Active Community:**
#     *   **Pro:** Python has a massive global community. This means:
#         *   Abundant resources: tutorials, documentation, forums, Stack Overflow answers.
#         *   Easier to find help and solutions to problems.
#         *   Constant development and improvement of the language and its libraries.
#
# 5.  **Rapid Development and Prototyping:**
#     *   **Pro:** Due to its high-level nature, extensive libraries, and simple syntax, Python allows developers to write less code and achieve more functionality in a shorter amount of time. This makes it ideal for rapid prototyping and agile development methodologies.
#
# 6.  **Cross-Platform Compatibility:**
#     *   **Pro:** Python code can run on various operating systems (Windows, macOS, Linux, Unix) with little or no modification, thanks to its interpreter being available on these platforms.
#
# 7.  **Support for Multiple Programming Paradigms:**
#     *   **Pro:** Python supports object-oriented, imperative, and functional programming paradigms, giving developers flexibility in how they structure their code.
#
# ---
#
# ### Cons of Python
#
# 1.  **Performance/Speed Limitations:**
#     *   **Con:** Python is an interpreted language (as opposed to compiled languages like C++ or Java), which generally means slower execution speeds. For CPU-intensive tasks or applications requiring very low latency, Python might not be the best choice.
#
# 2.  **Global Interpreter Lock (GIL):**
#     *   **Con:** The GIL is a mechanism that allows only one thread to execute Python bytecode at a time, even on multi-core processors. While it simplifies memory management and prevents deadlocks, it effectively limits true parallelism for CPU-bound tasks. This means multi-threaded Python programs often don't fully utilize multiple CPU cores for heavy computation (though it's less of an issue for I/O-bound tasks).
#
# 3.  **Memory Consumption:**
#     *   **Con:** Python typically has a higher memory footprint compared to lower-level languages. This is due to its dynamic typing, object-oriented nature, and garbage collection mechanisms, which can be a concern for memory-constrained environments.
#
# 4.  **Dynamic Typing and Runtime Errors:**
#     *   **Con:** Python is dynamically typed, meaning type checking happens at runtime rather than compile-time. While this offers flexibility, it can lead to unexpected type-related errors that are only discovered when the specific part of the code is executed. Static type checkers (like MyPy) and type hints can mitigate this, but it's not enforced by the interpreter by default.
#
# 5.  **Not Native for Mobile or Browser Environments:**
#     *   **Con:** Python is not natively supported for building mobile applications (iOS/Android) or running directly in web browsers. While frameworks like Kivy or BeeWare exist for mobile, and WebAssembly can potentially run Python in browsers, JavaScript remains the dominant language for these platforms.
#
# 6.  **Indentation Sensitivity:**
#     *   **Con:** While a pro for readability, Python's strict reliance on indentation for defining code blocks can be a source of frustration and `IndentationError` bugs for new programmers or those coming from languages that use curly braces.
#
# ---
#
# ### Conclusion
#
# Python is an excellent choice for a vast array of applications, especially where **rapid development, readability, and access to a rich ecosystem are paramount**. It excels in web development, data science, machine learning, automation, and general scripting.
#
# However, if your project demands **absolute maximum performance, low-level hardware interaction, or native mobile/browser front-end development**, you might need to consider other languages or use Python in conjunction with them (e.g., using C/C++ for performance-critical components wrapped in Python).

# %%
from langchain_classic.chains import StuffDocumentsChain, LLMChain

# %%
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
document_chain=create_stuff_documents_chain(llm,prompt)
document_chain
# Out:
# RunnableBinding(bound=RunnableBinding(bound=RunnableAssign(mapper={
#   context: RunnableLambda(format_docs)
# }), kwargs={}, config={'run_name': 'format_inputs'}, config_factories=[])
# | ChatPromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, template='\nyou are a expert in research paper analysis. Answer the following question based only on the provided context:\n<context>\n{context}\n</context>\n'), additional_kwargs={})])
# | GoogleGenerativeAI(google_api_key=SecretStr('**********'), model='models/gemini-2.5-flash', client=ChatGoogleGenerativeAI(profile={'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), model='models/gemini-2.5-flash', client=<google.genai.client.Client object at 0x000002557F947A40>, default_metadata=(), model_kwargs={}))
# | StrOutputParser(), kwargs={}, config={'run_name': 'stuff_documents_chain'}, config_factories=[])

# %%
from langchain_classic.chains import create_retrieval_chain

retrieval_chain=create_retrieval_chain(retriever1,document_chain)
retrieval_chain
# Out:
# RunnableBinding(bound=RunnableAssign(mapper={
#   context: RunnableBinding(bound=RunnableLambda(lambda x: x['input'])
#            | VectorStoreRetriever(tags=['FAISS', 'HuggingFaceEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x00000254B4368B00>, search_kwargs={}), kwargs={}, config={'run_name': 'retrieve_documents'}, config_factories=[])
# })
# | RunnableAssign(mapper={
#     answer: RunnableBinding(bound=RunnableBinding(bound=RunnableAssign(mapper={
#               context: RunnableLambda(format_docs)
#             }), kwargs={}, config={'run_name': 'format_inputs'}, config_factories=[])
#             | ChatPromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context'], input_types={}, partial_variables={}, template='\nyou are a expert in research paper analysis. Answer the following question based only on the provided context:\n<context>\n{context}\n</context>\n'), additional_kwargs={})])
#             | GoogleGenerativeAI(google_api_key=SecretStr('**********'), model='models/gemini-2.5-flash', client=ChatGoogleGenerativeAI(profile={'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), model='models/gemini-2.5-flash', client=<google.genai.client.Client object at 0x000002557F947A40>, default_metadata=(), model_kwargs={}))
#             | StrOutputParser(), kwargs={}, config={'run_name': 'stuff_documents_chain'}, config_factories=[])
#   }), kwargs={}, config={'run_name': 'retrieval_chain'}, config_factories=[])

# %%
retrieval_chain.invoke({'input':"In mathematics, the term homomorphic refers to what?"})
# Out:
# {'input': 'In mathematics, the term homomorphic refers to what?',
#  'context': [Document(id='87379ae6-5e32-46b2-927b-acebc2119306', metadata={'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-03-28T21:00:13-04:00', 'moddate': '2023-03-28T21:00:13-04:00', 'title': '', 'subject': '', 'author': '', 'keywords': '', 'source': 'https://arxiv.org/pdf/2303.15563v1.pdf', 'total_pages': 13, 'page': 2, 'page_label': '3'}, page_content='ICLR 2023 W orkshop on Trustworthy Machine Learning for Heal thcare\nas the added noise hinders the inference of actual knowledge about the training data by the attacker.\nHowever, adding too much noise (i.e., high privacy budget) c an hamper learning and negatively\nimpact the model accuracy (Chilukoti et al., 2022).\n2.3 H O M O M O RP H IC EN CRY P T IO N\nIn mathematics, the term homomorphic refers to the transformation of a given set into another whil e\npreserving the relation between the elements in both sets. T hus, Homomorphic Encryption (HE)\nrefers to the conversion of plaintext into ciphertext while preserving the structure of the data. Con-\nsequently, speciﬁc operations applied to the ciphertext wi ll provide the same results as if they were\napplied to the plaintext but without compromising the encry ption (Acar et al., 2018). That is, the\nplaintext data is never accessed nor decrypted as the operat ions are directly applied to the encrypted'),
#   Document(id='90b98426-62ee-4804-84c7-4c25067b149b', metadata={'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-03-28T21:00:13-04:00', 'moddate': '2023-03-28T21:00:13-04:00', 'title': '', 'subject': '', 'author': '', 'keywords': '', 'source': 'https://arxiv.org/pdf/2303.15563v1.pdf', 'total_pages': 13, 'page': 2, 'page_label': '3'}, page_content='plaintext data is never accessed nor decrypted as the operat ions are directly applied to the encrypted\ndata. The result of the transformations on the ciphertext ca n only be decrypted back to plaintext by\nthe encryption key owner.\nDespite the beneﬁt of provable privacy guarantees, the rang e of operations available in HE is re-\nstricted to addition and multiplication i.e., fully homomorphic encryption. This limits the set\nand number of transformations applicable to the data and req uires the use of approximations for\nmore complex operations (e.g., HE-ReLU is the polynomial ap proximation of the ReLU function\n(Y ue et al., 2021b)). This also signiﬁcantly increases the c omputational time needed to process en-\ncrypted text compared to plaintext by several orders of magn itude (Popescu et al., 2021).\n2.4 S E CU RE MU LT I-PA RT Y CO M P U TAT IO N\nSecure Multi-Party Computation (SMPC) (Goldreich, 1998) p rovides a framework in which two or'),
#   Document(id='de98604b-abee-4309-802b-23df8dfd49d1', metadata={'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-03-28T21:00:13-04:00', 'moddate': '2023-03-28T21:00:13-04:00', 'title': '', 'subject': '', 'author': '', 'keywords': '', 'source': 'https://arxiv.org/pdf/2303.15563v1.pdf', 'total_pages': 13, 'page': 10, 'page_label': '11'}, page_content='ter, Constantin Suciu, and Lucian Mihai Itu. Privacy preser ving classiﬁcation of eeg data using\nmachine learning and homomorphic encryption. Applied Sciences , 11(16):7360, 2021.\nAdnan Qayyum, Junaid Qadir, Muhammad Bilal, and Ala Al-Fuqa ha. Secure and robust machine\nlearning for healthcare: A survey. IEEE Reviews in Biomedical Engineering , 14:156–180, 2020.\nDhanesh Ramachandram and Graham W T aylor. Deep multimodal l earning: A survey on recent\nadvances and trends. IEEE signal processing magazine , 34(6):96–108, 2017.\n11'),
#   Document(id='525917f2-80d4-41b4-9fb3-5185650511b7', metadata={'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-03-28T21:00:13-04:00', 'moddate': '2023-03-28T21:00:13-04:00', 'title': '', 'subject': '', 'author': '', 'keywords': '', 'source': 'https://arxiv.org/pdf/2303.15563v1.pdf', 'total_pages': 13, 'page': 10, 'page_label': '11'}, page_content='David Ouyang, Bryan He, Amirata Ghorbani, Neal Y uan, Joseph Ebinger, Curtis P Langlotz, Paul A\nHeidenreich, Robert A Harrington, David H Liang, Euan A Ashl ey, et al. V ideo-based ai for\nbeat-to-beat assessment of cardiac function. Nature, 580(7802):252–256, 2020.\nSangjoon Park, Gwanghyun Kim, Jeongsol Kim, Boah Kim, and Jo ng Chul Y e. Federated\nsplit vision transformer for covid-19 cxr diagnosis using t ask-agnostic training. arXiv preprint\narXiv:2111.01338 , 2021.\nJestine Paul, Meenatchi Sundaram Muthu Selva Annamalai, Wi lliam Ming, Ahmad Al Badawi,\nBharadwaj V eeravalli, and Khin Mi Mi Aung. Privacy-preserv ing collective learning with homo-\nmorphic encryption. IEEE Access , 9:132084–132096, 2021.\nAndreea Bianca Popescu, Ioana Antonia T aca, Cosmin Ioan Nit a, Anamaria V izitiu, Robert Deme-\nter, Constantin Suciu, and Lucian Mihai Itu. Privacy preser ving classiﬁcation of eeg data using\nmachine learning and homomorphic encryption. Applied Sciences , 11(16):7360, 2021.')],
#  'answer': 'Based on the provided context, Homomorphic Encryption (HE) can be described as follows:\n\nHomomorphic Encryption (HE) is a cryptographic technique that involves converting plaintext data into ciphertext while **preserving the inherent structure of the data**. The term "homomorphic" in mathematics refers to a transformation that maintains the relations between elements when converting one set to another.\n\n**Key characteristics and functionalities of HE:**\n\n*   **Operation on Ciphertext:** It allows specific operations (e.g., addition and multiplication) to be applied directly to the encrypted data (ciphertext). Crucially, these operations yield the same results as if they were applied to the original plaintext, **without ever accessing or decrypting the plaintext data**.\n*   **Privacy Guarantees:** HE offers the benefit of **provable privacy guarantees** because the data remains encrypted throughout computations.\n*   **Decryption:** The results of transformations performed on the ciphertext can only be decrypted back to plaintext by the **encryption key owner**.\n\n**Limitations of HE:**\n\n*   **Restricted Operations:** The range of operations available in HE, particularly fully homomorphic encryption, is currently restricted primarily to **addition and multiplication**.\n*   **Approximations for Complex Operations:** This limitation necessitates the use of **approximations for more complex operations**. For instance, the ReLU function often requires a polynomial approximation, referred to as HE-ReLU (Yue et al., 2021b).\n*   **High Computational Cost:** HE significantly increases the **computational time** needed to process encrypted text compared to plaintext, by several orders of magnitude (Popescu et al., 2021).'}
